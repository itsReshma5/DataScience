# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-65a9b030-167f-4797-ad59-ea496100b80f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65a9b030-167f-4797-ad59-ea496100b80f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd


file_path = "/content/labeled_data.csv"
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
#Exploring Data using DataFrames
print(df.shape)
# Get column names
print(df.columns)
print(df.dtypes)
# Check for missing values
print(df.isnull().sum())

# %%
#Index objects
print(df.index)
# Out:
# RangeIndex(start=0, stop=24783, step=1)

# %%
# Reindex the DataFrame (example)
new_index = [0, 2, 5, 10]  # Replace with valid indices
df_reind = df.reindex(new_index)
print(df_reind)
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 2            2      3            0                   3        0      1
# 5            5      3            1                   2        0      1
# 10          10      3            0                   3        0      1
#
#                                                 tweet
# 0   !!! RT @mayasolovely: As a woman you shouldn't...
# 2   !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 5   !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
# 10  " Keeks is a bitch she curves everyone " lol I...

# %%
# Drop a row by index
df_dropped_row = df.drop(index=[0, 1])  # Drops first two rows
print(df_dropped_row.head())

# %%
# Select a single column
print(df["count"])
print(df[["count", "class"]])

# Select rows by index
print(df.iloc[0])  # First row
print(df.iloc[1:5])  # Rows from index 1 to 4

# Select rows based on a condition
print(df[df["count"] > 6])  # Replace with actual column name and condition

# %%
# data alignment
aligned_data = df1.add(df2, fill_value=0)
print(aligned_data)

# %%
aligned_data.dropna()
print(aligned_data)

# %%
# Rank
df["rank"] = df["count"].rank()
df_sorted = df.sort_values(by="offensive_language", ascending=False)
print(df_sorted.head())

# %%
# Basic statistics
print(df.describe())
print(df["tweet"].nunique())
print(df["tweet"].mode())

# %%
#multi-index Df
arrays = [["A", "A", "B", "B"], ["one", "two", "one", "two"]]
index = pd.MultiIndex.from_arrays(arrays, names=("Letters", "Numbers"))
df_multi = pd.DataFrame({"Values": [1, 2, 3, 4]}, index=index)
print(df_multi)
